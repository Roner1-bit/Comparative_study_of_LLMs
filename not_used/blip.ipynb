# %%
from transformers import BlipForConditionalGeneration, BlipProcessor
from PIL import Image
import os
import requests
# Out:
# /home/elboardy/anaconda3/envs/blip/lib/python3.9/site-packages/torchvision/datapoints/__init__.py:12: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# /home/elboardy/anaconda3/envs/blip/lib/python3.9/site-packages/torchvision/transforms/v2/__init__.py:54: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)

# %%
# Define paths
cases_dir = '/media/RLAB-Disk01/(final)merged_images_with_labels_order_and_folders_mask_normalized/'
cache_dir = '/media/RLAB-Disk01/Large-Language-Models-Weights'

# %%
# Collect list of cases that do not have 'blip-response.txt'
cases_to_process = []
for case in os.listdir(cases_dir):
    case_dir = os.path.join(cases_dir, case)
    if os.path.isdir(case_dir):
        response_path = os.path.join(case_dir, 'blip-response.txt')
        if not os.path.exists(response_path):
            cases_to_process.append(case)
print(f"Found {len(cases_to_process)} cases to process.")
# Out:
# Found 40 cases to process.

# %%
# Load the BLIP model and processor
print("Loading BLIP model and processor...")
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base", cache_dir=cache_dir)
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base", cache_dir=cache_dir)
print("BLIP model and processor loaded successfully!\n")

def load_image(image_path):
    try:
        img = Image.open(image_path)
        return img
    except Exception as e:
        print(f"Error loading image {image_path}: {e}")
        return None
# Out:
# Loading BLIP model and processor...
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# /home/elboardy/anaconda3/envs/blip/lib/python3.9/site-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# BLIP model and processor loaded successfully!

# %%
failed_cases = []

# Iterate through cases in the directory
for case in cases_to_process:
    case_dir = os.path.join(cases_dir, case)
    if not os.path.isdir(case_dir):
        continue  # Skip non-directory files

    image_files = [f for f in os.listdir(case_dir) if f.lower().endswith('.png')]
    print(f"Found {len(image_files)} image files for case {case}")

    # Collect and process images
    captions = []
    for image_file in image_files:
        image_path = os.path.join(case_dir, image_file)
        img = load_image(image_path)
        if img is not None:
            print(f"Generating caption for image: {image_file} in case {case}")
            # Preprocess the image
            inputs = processor(images=img, return_tensors="pt")
            # Generate caption
            out = model.generate(**inputs, max_length=2048, num_beams=6)
            # Decode the generated text
            caption = processor.decode(out[0], skip_special_tokens=True)
            captions.append(f"Image: {image_file}\nCaption: {caption}\n")
            print(f"Generated caption for {image_file}: {caption}")
        else:
            print(f"Skipping invalid image: {image_file} in case {case}")

    if captions:
        # Save the captions to a text file
        response_path = os.path.join(case_dir, 'blip-response.txt')
        with open(response_path, 'w', encoding='utf-8') as f:
            f.write("\n".join(captions))
        print(f"Captions saved for case {case}.")
    else:
        print(f"No valid images to process for case {case}.")
        continue

    # Memory management
    del inputs, out, caption
    print(f"Memory cleared for case {case}")

# After processing all cases, save failed cases
failed_cases_path = os.path.join(cases_dir, 'failed_cases_blip.txt')
with open(failed_cases_path, 'w', encoding='utf-8') as f:
    for failed_case in failed_cases:
        f.write(f"{failed_case}\n")
print(f"Failed cases logged in {failed_cases_path}")
# Out:
# Found 9 image files for case RHUH-0019
# Generating caption for image: RHUH-0019_batch_1.png in case RHUH-0019
# Generated caption for RHUH-0019_batch_1.png: a black and white image of a bunch of flowers
# Generating caption for image: RHUH-0019_batch_2.png in case RHUH-0019
# Generated caption for RHUH-0019_batch_2.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0019_batch_3.png in case RHUH-0019
# Generated caption for RHUH-0019_batch_3.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0019_batch_4.png in case RHUH-0019
# Generated caption for RHUH-0019_batch_4.png: a black and white image of a number of different circles
# Generating caption for image: RHUH-0019_batch_5.png in case RHUH-0019
# Generated caption for RHUH-0019_batch_5.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0019_batch_6.png in case RHUH-0019
# Generated caption for RHUH-0019_batch_6.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0019_batch_7.png in case RHUH-0019
# Generated caption for RHUH-0019_batch_7.png: a black and white photo of a number of dots
# Generating caption for image: RHUH-0019_batch_8.png in case RHUH-0019
# Generated caption for RHUH-0019_batch_8.png: a black and white image of a number of dots
# Generating caption for image: RHUH-0019_batch_9.png in case RHUH-0019
# Generated caption for RHUH-0019_batch_9.png: a black and white image of a black and white image of a black and white image of a black and
# Captions saved for case RHUH-0019.
# Memory cleared for case RHUH-0019
# Found 6 image files for case RHUH-0001
# Generating caption for image: RHUH-0001_batch_1.png in case RHUH-0001
# Generated caption for RHUH-0001_batch_1.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0001_batch_2.png in case RHUH-0001
# Generated caption for RHUH-0001_batch_2.png: an mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri
# Generating caption for image: RHUH-0001_batch_3.png in case RHUH-0001
# Generated caption for RHUH-0001_batch_3.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0001_batch_4.png in case RHUH-0001
# Generated caption for RHUH-0001_batch_4.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0001_batch_5.png in case RHUH-0001
# Generated caption for RHUH-0001_batch_5.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0001_batch_6.png in case RHUH-0001
# Generated caption for RHUH-0001_batch_6.png: an image of the different phases of the moon
# Captions saved for case RHUH-0001.
# Memory cleared for case RHUH-0001
# Found 6 image files for case RHUH-0002
# Generating caption for image: RHUH-0002_batch_1.png in case RHUH-0002
# Generated caption for RHUH-0002_batch_1.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0002_batch_2.png in case RHUH-0002
# Generated caption for RHUH-0002_batch_2.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0002_batch_3.png in case RHUH-0002
# Generated caption for RHUH-0002_batch_3.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0002_batch_4.png in case RHUH-0002
# Generated caption for RHUH-0002_batch_4.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0002_batch_5.png in case RHUH-0002
# Generated caption for RHUH-0002_batch_5.png: a black and white image of a number of jellys
# Generating caption for image: RHUH-0002_batch_6.png in case RHUH-0002
# Generated caption for RHUH-0002_batch_6.png: a black and white image shows the different areas of the earth ' s surface
# Captions saved for case RHUH-0002.
# Memory cleared for case RHUH-0002
# Found 6 image files for case RHUH-0003
# Generating caption for image: RHUH-0003_batch_1.png in case RHUH-0003
# Generated caption for RHUH-0003_batch_1.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0003_batch_2.png in case RHUH-0003
# Generated caption for RHUH-0003_batch_2.png: a black and white image of a bunch of coins
# Generating caption for image: RHUH-0003_batch_3.png in case RHUH-0003
# Generated caption for RHUH-0003_batch_3.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0003_batch_4.png in case RHUH-0003
# Generated caption for RHUH-0003_batch_4.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0003_batch_5.png in case RHUH-0003
# Generated caption for RHUH-0003_batch_5.png: a black and white image of a row of diamonds
# Generating caption for image: RHUH-0003_batch_6.png in case RHUH-0003
# Generated caption for RHUH-0003_batch_6.png: an mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri
# Captions saved for case RHUH-0003.
# Memory cleared for case RHUH-0003
# Found 7 image files for case RHUH-0004
# Generating caption for image: RHUH-0004_batch_1.png in case RHUH-0004
# Generated caption for RHUH-0004_batch_1.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0004_batch_2.png in case RHUH-0004
# Generated caption for RHUH-0004_batch_2.png: an image of a large group of small, gray circles
# Generating caption for image: RHUH-0004_batch_3.png in case RHUH-0004
# Generated caption for RHUH-0004_batch_3.png: a black and white image of a bunch of flowers
# Generating caption for image: RHUH-0004_batch_4.png in case RHUH-0004
# Generated caption for RHUH-0004_batch_4.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0004_batch_5.png in case RHUH-0004
# Generated caption for RHUH-0004_batch_5.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0004_batch_6.png in case RHUH-0004
# Generated caption for RHUH-0004_batch_6.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0004_batch_7.png in case RHUH-0004
# Generated caption for RHUH-0004_batch_7.png: a black and white image of a group of jellys
# Captions saved for case RHUH-0004.
# Memory cleared for case RHUH-0004
# Found 6 image files for case RHUH-0005
# Generating caption for image: RHUH-0005_batch_1.png in case RHUH-0005
# Generated caption for RHUH-0005_batch_1.png: an image of a number of small, round, black and white dots on a black background
# Generating caption for image: RHUH-0005_batch_2.png in case RHUH-0005
# Generated caption for RHUH-0005_batch_2.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0005_batch_3.png in case RHUH-0005
# Generated caption for RHUH-0005_batch_3.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0005_batch_4.png in case RHUH-0005
# Generated caption for RHUH-0005_batch_4.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0005_batch_5.png in case RHUH-0005
# Generated caption for RHUH-0005_batch_5.png: a black and white image of a number of dots
# Generating caption for image: RHUH-0005_batch_6.png in case RHUH-0005
# Generated caption for RHUH-0005_batch_6.png: a black and white image of a group of asteroids
# Captions saved for case RHUH-0005.
# Memory cleared for case RHUH-0005
# Found 8 image files for case RHUH-0006
# Generating caption for image: RHUH-0006_batch_1.png in case RHUH-0006
# Generated caption for RHUH-0006_batch_1.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0006_batch_2.png in case RHUH-0006
# Generated caption for RHUH-0006_batch_2.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0006_batch_3.png in case RHUH-0006
# Generated caption for RHUH-0006_batch_3.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0006_batch_4.png in case RHUH-0006
# Generated caption for RHUH-0006_batch_4.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0006_batch_5.png in case RHUH-0006
# Generated caption for RHUH-0006_batch_5.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0006_batch_6.png in case RHUH-0006
# Generated caption for RHUH-0006_batch_6.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0006_batch_7.png in case RHUH-0006
# Generated caption for RHUH-0006_batch_7.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0006_batch_8.png in case RHUH-0006
# Generated caption for RHUH-0006_batch_8.png: a black and white image of a group of asteroids
# Captions saved for case RHUH-0006.
# Memory cleared for case RHUH-0006
# Found 7 image files for case RHUH-0007
# Generating caption for image: RHUH-0007_batch_1.png in case RHUH-0007
# Generated caption for RHUH-0007_batch_1.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0007_batch_2.png in case RHUH-0007
# Generated caption for RHUH-0007_batch_2.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0007_batch_3.png in case RHUH-0007
# Generated caption for RHUH-0007_batch_3.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0007_batch_4.png in case RHUH-0007
# Generated caption for RHUH-0007_batch_4.png: an image of a number of small, irregular, irregular, irregular, irregular, irregular, irregular, irregular
# Generating caption for image: RHUH-0007_batch_5.png in case RHUH-0007
# Generated caption for RHUH-0007_batch_5.png: an image of a number of different sizes of diamonds
# Generating caption for image: RHUH-0007_batch_6.png in case RHUH-0007
# Generated caption for RHUH-0007_batch_6.png: a black and white image of a number of different circles
# Generating caption for image: RHUH-0007_batch_7.png in case RHUH-0007
# Generated caption for RHUH-0007_batch_7.png: a black and white image of a number of shells
# Captions saved for case RHUH-0007.
# Memory cleared for case RHUH-0007
# Found 7 image files for case RHUH-0008
# Generating caption for image: RHUH-0008_batch_1.png in case RHUH-0008
# Generated caption for RHUH-0008_batch_1.png: a black and white image of a bunch of flowers
# Generating caption for image: RHUH-0008_batch_2.png in case RHUH-0008
# Generated caption for RHUH-0008_batch_2.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0008_batch_3.png in case RHUH-0008
# Generated caption for RHUH-0008_batch_3.png: a black and white image of a group of small spheres
# Generating caption for image: RHUH-0008_batch_4.png in case RHUH-0008
# Generated caption for RHUH-0008_batch_4.png: a black and white image of a bunch of flowers
# Generating caption for image: RHUH-0008_batch_5.png in case RHUH-0008
# Generated caption for RHUH-0008_batch_5.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0008_batch_6.png in case RHUH-0008
# Generated caption for RHUH-0008_batch_6.png: the phases of the moon, showing the phases of the moon and the phases of the phases of the moon
# Generating caption for image: RHUH-0008_batch_7.png in case RHUH-0008
# Generated caption for RHUH-0008_batch_7.png: an image of a group of chromosomes, showing the different chromosomes that are present in each species
# Captions saved for case RHUH-0008.
# Memory cleared for case RHUH-0008
# Found 8 image files for case RHUH-0009
# Generating caption for image: RHUH-0009_batch_1.png in case RHUH-0009
# Generated caption for RHUH-0009_batch_1.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0009_batch_2.png in case RHUH-0009
# Generated caption for RHUH-0009_batch_2.png: an image of a group of skulls on a black background
# Generating caption for image: RHUH-0009_batch_3.png in case RHUH-0009
# Generated caption for RHUH-0009_batch_3.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0009_batch_4.png in case RHUH-0009
# Generated caption for RHUH-0009_batch_4.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0009_batch_5.png in case RHUH-0009
# Generated caption for RHUH-0009_batch_5.png: an mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri
# Generating caption for image: RHUH-0009_batch_6.png in case RHUH-0009
# Generated caption for RHUH-0009_batch_6.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0009_batch_7.png in case RHUH-0009
# Generated caption for RHUH-0009_batch_7.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0009_batch_8.png in case RHUH-0009
# Generated caption for RHUH-0009_batch_8.png: a black and white image of a number of circles
# Captions saved for case RHUH-0009.
# Memory cleared for case RHUH-0009
# Found 5 image files for case RHUH-0010
# Generating caption for image: RHUH-0010_batch_1.png in case RHUH-0010
# Generated caption for RHUH-0010_batch_1.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0010_batch_2.png in case RHUH-0010
# Generated caption for RHUH-0010_batch_2.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0010_batch_3.png in case RHUH-0010
# Generated caption for RHUH-0010_batch_3.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0010_batch_4.png in case RHUH-0010
# Generated caption for RHUH-0010_batch_4.png: a black and white image of a bunch of flowers
# Generating caption for image: RHUH-0010_batch_5.png in case RHUH-0010
# Generated caption for RHUH-0010_batch_5.png: a black and white image of planets with the sun in the background
# Captions saved for case RHUH-0010.
# Memory cleared for case RHUH-0010
# Found 7 image files for case RHUH-0011
# Generating caption for image: RHUH-0011_batch_1.png in case RHUH-0011
# Generated caption for RHUH-0011_batch_1.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0011_batch_2.png in case RHUH-0011
# Generated caption for RHUH-0011_batch_2.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0011_batch_3.png in case RHUH-0011
# Generated caption for RHUH-0011_batch_3.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0011_batch_4.png in case RHUH-0011
# Generated caption for RHUH-0011_batch_4.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0011_batch_5.png in case RHUH-0011
# Generated caption for RHUH-0011_batch_5.png: a black and white image of skulls on a black background
# Generating caption for image: RHUH-0011_batch_6.png in case RHUH-0011
# Generated caption for RHUH-0011_batch_6.png: an image of a number of different types of the human brain
# Generating caption for image: RHUH-0011_batch_7.png in case RHUH-0011
# Generated caption for RHUH-0011_batch_7.png: mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri
# Captions saved for case RHUH-0011.
# Memory cleared for case RHUH-0011
# Found 9 image files for case RHUH-0012
# Generating caption for image: RHUH-0012_batch_1.png in case RHUH-0012
# Generated caption for RHUH-0012_batch_1.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0012_batch_2.png in case RHUH-0012
# Generated caption for RHUH-0012_batch_2.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0012_batch_3.png in case RHUH-0012
# Generated caption for RHUH-0012_batch_3.png: a black and white image of a number of different circles
# Generating caption for image: RHUH-0012_batch_4.png in case RHUH-0012
# Generated caption for RHUH-0012_batch_4.png: a black and white image of a number of people ' s faces
# Generating caption for image: RHUH-0012_batch_5.png in case RHUH-0012
# Generated caption for RHUH-0012_batch_5.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0012_batch_6.png in case RHUH-0012
# Generated caption for RHUH-0012_batch_6.png: a black and white photo of circles of different sizes
# Generating caption for image: RHUH-0012_batch_7.png in case RHUH-0012
# Generated caption for RHUH-0012_batch_7.png: a black and white image of a number of dots
# Generating caption for image: RHUH-0012_batch_8.png in case RHUH-0012
# Generated caption for RHUH-0012_batch_8.png: a black and white photo of a group of dots
# Generating caption for image: RHUH-0012_batch_9.png in case RHUH-0012
# Generated caption for RHUH-0012_batch_9.png: a black and white image of a group of asteroids
# Captions saved for case RHUH-0012.
# Memory cleared for case RHUH-0012
# Found 9 image files for case RHUH-0013
# Generating caption for image: RHUH-0013_batch_1.png in case RHUH-0013
# Generated caption for RHUH-0013_batch_1.png: an image of a black and white image of a black and white image of a black and white image of a black and white image of a
# Generating caption for image: RHUH-0013_batch_2.png in case RHUH-0013
# Generated caption for RHUH-0013_batch_2.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0013_batch_3.png in case RHUH-0013
# Generated caption for RHUH-0013_batch_3.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0013_batch_4.png in case RHUH-0013
# Generated caption for RHUH-0013_batch_4.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0013_batch_5.png in case RHUH-0013
# Generated caption for RHUH-0013_batch_5.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0013_batch_6.png in case RHUH-0013
# Generated caption for RHUH-0013_batch_6.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0013_batch_7.png in case RHUH-0013
# Generated caption for RHUH-0013_batch_7.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0013_batch_8.png in case RHUH-0013
# Generated caption for RHUH-0013_batch_8.png: an image of a group of small, round, black and white circles
# Generating caption for image: RHUH-0013_batch_9.png in case RHUH-0013
# Generated caption for RHUH-0013_batch_9.png: a black and white image of a number of circles on a black background
# Captions saved for case RHUH-0013.
# Memory cleared for case RHUH-0013
# Found 11 image files for case RHUH-0014
# Generating caption for image: RHUH-0014_batch_1.png in case RHUH-0014
# Generated caption for RHUH-0014_batch_1.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0014_batch_10.png in case RHUH-0014
# Generated caption for RHUH-0014_batch_10.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0014_batch_11.png in case RHUH-0014
# Generated caption for RHUH-0014_batch_11.png: a black and white image of a black and white image of a black and white image of a black and
# Generating caption for image: RHUH-0014_batch_2.png in case RHUH-0014
# Generated caption for RHUH-0014_batch_2.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0014_batch_3.png in case RHUH-0014
# Generated caption for RHUH-0014_batch_3.png: a black and white image of a bunch of flowers
# Generating caption for image: RHUH-0014_batch_4.png in case RHUH-0014
# Generated caption for RHUH-0014_batch_4.png: an image of the human brain showing the different areas of the brain
# Generating caption for image: RHUH-0014_batch_5.png in case RHUH-0014
# Generated caption for RHUH-0014_batch_5.png: an image of a number of black and white dots on a black background
# Generating caption for image: RHUH-0014_batch_6.png in case RHUH-0014
# Generated caption for RHUH-0014_batch_6.png: a black and white image of a number of small circles of different sizes
# Generating caption for image: RHUH-0014_batch_7.png in case RHUH-0014
# Generated caption for RHUH-0014_batch_7.png: an mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri
# Generating caption for image: RHUH-0014_batch_8.png in case RHUH-0014
# Generated caption for RHUH-0014_batch_8.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0014_batch_9.png in case RHUH-0014
# Generated caption for RHUH-0014_batch_9.png: a black and white image of a number of circles
# Captions saved for case RHUH-0014.
# Memory cleared for case RHUH-0014
# Found 6 image files for case RHUH-0015
# Generating caption for image: RHUH-0015_batch_1.png in case RHUH-0015
# Generated caption for RHUH-0015_batch_1.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0015_batch_2.png in case RHUH-0015
# Generated caption for RHUH-0015_batch_2.png: a black and white image of a number of diamonds
# Generating caption for image: RHUH-0015_batch_3.png in case RHUH-0015
# Generated caption for RHUH-0015_batch_3.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0015_batch_4.png in case RHUH-0015
# Generated caption for RHUH-0015_batch_4.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0015_batch_5.png in case RHUH-0015
# Generated caption for RHUH-0015_batch_5.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0015_batch_6.png in case RHUH-0015
# Generated caption for RHUH-0015_batch_6.png: a black and white photo of the moon
# Captions saved for case RHUH-0015.
# Memory cleared for case RHUH-0015
# Found 7 image files for case RHUH-0016
# Generating caption for image: RHUH-0016_batch_1.png in case RHUH-0016
# Generated caption for RHUH-0016_batch_1.png: a black and white image of skulls on a black background
# Generating caption for image: RHUH-0016_batch_2.png in case RHUH-0016
# Generated caption for RHUH-0016_batch_2.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0016_batch_3.png in case RHUH-0016
# Generated caption for RHUH-0016_batch_3.png: a black and white image of a number of different eyes
# Generating caption for image: RHUH-0016_batch_4.png in case RHUH-0016
# Generated caption for RHUH-0016_batch_4.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0016_batch_5.png in case RHUH-0016
# Generated caption for RHUH-0016_batch_5.png: a black and white image of a number of eyes
# Generating caption for image: RHUH-0016_batch_6.png in case RHUH-0016
# Generated caption for RHUH-0016_batch_6.png: a black and white image of a number of fingerprints
# Generating caption for image: RHUH-0016_batch_7.png in case RHUH-0016
# Generated caption for RHUH-0016_batch_7.png: a black and white image of a group of asteroids
# Captions saved for case RHUH-0016.
# Memory cleared for case RHUH-0016
# Found 6 image files for case RHUH-0017
# Generating caption for image: RHUH-0017_batch_1.png in case RHUH-0017
# Generated caption for RHUH-0017_batch_1.png: a black and white image of a group of fish
# Generating caption for image: RHUH-0017_batch_2.png in case RHUH-0017
# Generated caption for RHUH-0017_batch_2.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0017_batch_3.png in case RHUH-0017
# Generated caption for RHUH-0017_batch_3.png: a black and white image of a number of rocks
# Generating caption for image: RHUH-0017_batch_4.png in case RHUH-0017
# Generated caption for RHUH-0017_batch_4.png: a black and white image of a number of small white dots on a black background
# Generating caption for image: RHUH-0017_batch_5.png in case RHUH-0017
# Generated caption for RHUH-0017_batch_5.png: a black and white image of a number of small dots
# Generating caption for image: RHUH-0017_batch_6.png in case RHUH-0017
# Generated caption for RHUH-0017_batch_6.png: a black and white image shows the different areas of the human body, including the different areas of the body
# Captions saved for case RHUH-0017.
# Memory cleared for case RHUH-0017
# Found 8 image files for case RHUH-0018
# Generating caption for image: RHUH-0018_batch_1.png in case RHUH-0018
# Generated caption for RHUH-0018_batch_1.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0018_batch_2.png in case RHUH-0018
# Generated caption for RHUH-0018_batch_2.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0018_batch_3.png in case RHUH-0018
# Generated caption for RHUH-0018_batch_3.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0018_batch_4.png in case RHUH-0018
# Generated caption for RHUH-0018_batch_4.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0018_batch_5.png in case RHUH-0018
# Generated caption for RHUH-0018_batch_5.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0018_batch_6.png in case RHUH-0018
# Generated caption for RHUH-0018_batch_6.png: an image of a number of small, round, black and white objects
# Generating caption for image: RHUH-0018_batch_7.png in case RHUH-0018
# Generated caption for RHUH-0018_batch_7.png: an image of a large group of small, round, black and white objects
# Generating caption for image: RHUH-0018_batch_8.png in case RHUH-0018
# Generated caption for RHUH-0018_batch_8.png: a black and white image of a number of circles
# Captions saved for case RHUH-0018.
# Memory cleared for case RHUH-0018
# Found 8 image files for case RHUH-0020
# Generating caption for image: RHUH-0020_batch_1.png in case RHUH-0020
# Generated caption for RHUH-0020_batch_1.png: an image of a number of skulls on a black background
# Generating caption for image: RHUH-0020_batch_2.png in case RHUH-0020
# Generated caption for RHUH-0020_batch_2.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0020_batch_3.png in case RHUH-0020
# Generated caption for RHUH-0020_batch_3.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0020_batch_4.png in case RHUH-0020
# Generated caption for RHUH-0020_batch_4.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0020_batch_5.png in case RHUH-0020
# Generated caption for RHUH-0020_batch_5.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0020_batch_6.png in case RHUH-0020
# Generated caption for RHUH-0020_batch_6.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0020_batch_7.png in case RHUH-0020
# Generated caption for RHUH-0020_batch_7.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0020_batch_8.png in case RHUH-0020
# Generated caption for RHUH-0020_batch_8.png: a black and white image of a number of jellys
# Captions saved for case RHUH-0020.
# Memory cleared for case RHUH-0020
# Found 6 image files for case RHUH-0021
# Generating caption for image: RHUH-0021_batch_1.png in case RHUH-0021
# Generated caption for RHUH-0021_batch_1.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0021_batch_2.png in case RHUH-0021
# Generated caption for RHUH-0021_batch_2.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0021_batch_3.png in case RHUH-0021
# Generated caption for RHUH-0021_batch_3.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0021_batch_4.png in case RHUH-0021
# Generated caption for RHUH-0021_batch_4.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0021_batch_5.png in case RHUH-0021
# Generated caption for RHUH-0021_batch_5.png: a black and white image of a number of small circles of different sizes
# Generating caption for image: RHUH-0021_batch_6.png in case RHUH-0021
# Generated caption for RHUH-0021_batch_6.png: a black and white image of water droplets on a black background
# Captions saved for case RHUH-0021.
# Memory cleared for case RHUH-0021
# Found 7 image files for case RHUH-0022
# Generating caption for image: RHUH-0022_batch_1.png in case RHUH-0022
# Generated caption for RHUH-0022_batch_1.png: a black and white image of a bunch of flowers
# Generating caption for image: RHUH-0022_batch_2.png in case RHUH-0022
# Generated caption for RHUH-0022_batch_2.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0022_batch_3.png in case RHUH-0022
# Generated caption for RHUH-0022_batch_3.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0022_batch_4.png in case RHUH-0022
# Generated caption for RHUH-0022_batch_4.png: a black and white image of a bunch of flowers
# Generating caption for image: RHUH-0022_batch_5.png in case RHUH-0022
# Generated caption for RHUH-0022_batch_5.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0022_batch_6.png in case RHUH-0022
# Generated caption for RHUH-0022_batch_6.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0022_batch_7.png in case RHUH-0022
# Generated caption for RHUH-0022_batch_7.png: a black and white image of a number of small white dots
# Captions saved for case RHUH-0022.
# Memory cleared for case RHUH-0022
# Found 7 image files for case RHUH-0023
# Generating caption for image: RHUH-0023_batch_1.png in case RHUH-0023
# Generated caption for RHUH-0023_batch_1.png: a black and white image of a line of dots
# Generating caption for image: RHUH-0023_batch_2.png in case RHUH-0023
# Generated caption for RHUH-0023_batch_2.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0023_batch_3.png in case RHUH-0023
# Generated caption for RHUH-0023_batch_3.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0023_batch_4.png in case RHUH-0023
# Generated caption for RHUH-0023_batch_4.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0023_batch_5.png in case RHUH-0023
# Generated caption for RHUH-0023_batch_5.png: a black and white image of a row of diamonds
# Generating caption for image: RHUH-0023_batch_6.png in case RHUH-0023
# Generated caption for RHUH-0023_batch_6.png: a set of six rows of diamonds on a black background
# Generating caption for image: RHUH-0023_batch_7.png in case RHUH-0023
# Generated caption for RHUH-0023_batch_7.png: a black and white image of a number of circles
# Captions saved for case RHUH-0023.
# Memory cleared for case RHUH-0023
# Found 5 image files for case RHUH-0024
# Generating caption for image: RHUH-0024_batch_1.png in case RHUH-0024
# Generated caption for RHUH-0024_batch_1.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0024_batch_2.png in case RHUH-0024
# Generated caption for RHUH-0024_batch_2.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0024_batch_3.png in case RHUH-0024
# Generated caption for RHUH-0024_batch_3.png: a black and white image of a group of small, round, black and white dots
# Generating caption for image: RHUH-0024_batch_4.png in case RHUH-0024
# Generated caption for RHUH-0024_batch_4.png: a row of black diamonds on a black background
# Generating caption for image: RHUH-0024_batch_5.png in case RHUH-0024
# Generated caption for RHUH-0024_batch_5.png: an image shows the different types of the human brain
# Captions saved for case RHUH-0024.
# Memory cleared for case RHUH-0024
# Found 4 image files for case RHUH-0025
# Generating caption for image: RHUH-0025_batch_1.png in case RHUH-0025
# Generated caption for RHUH-0025_batch_1.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0025_batch_2.png in case RHUH-0025
# Generated caption for RHUH-0025_batch_2.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0025_batch_3.png in case RHUH-0025
# Generated caption for RHUH-0025_batch_3.png: a black and white image of a group of jellyfishs
# Generating caption for image: RHUH-0025_batch_4.png in case RHUH-0025
# Generated caption for RHUH-0025_batch_4.png: a set of four rows of diamonds on a black background
# Captions saved for case RHUH-0025.
# Memory cleared for case RHUH-0025
# Found 5 image files for case RHUH-0026
# Generating caption for image: RHUH-0026_batch_1.png in case RHUH-0026
# Generated caption for RHUH-0026_batch_1.png: an image of a group of small, round, black and white dots
# Generating caption for image: RHUH-0026_batch_2.png in case RHUH-0026
# Generated caption for RHUH-0026_batch_2.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0026_batch_3.png in case RHUH-0026
# Generated caption for RHUH-0026_batch_3.png: a black and white image of a number of dots
# Generating caption for image: RHUH-0026_batch_4.png in case RHUH-0026
# Generated caption for RHUH-0026_batch_4.png: a black and white image of a number of dots
# Generating caption for image: RHUH-0026_batch_5.png in case RHUH-0026
# Generated caption for RHUH-0026_batch_5.png: a black and white photo of a bunch of diamonds
# Captions saved for case RHUH-0026.
# Memory cleared for case RHUH-0026
# Found 8 image files for case RHUH-0027
# Generating caption for image: RHUH-0027_batch_1.png in case RHUH-0027
# Generated caption for RHUH-0027_batch_1.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0027_batch_2.png in case RHUH-0027
# Generated caption for RHUH-0027_batch_2.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0027_batch_3.png in case RHUH-0027
# Generated caption for RHUH-0027_batch_3.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0027_batch_4.png in case RHUH-0027
# Generated caption for RHUH-0027_batch_4.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0027_batch_5.png in case RHUH-0027
# Generated caption for RHUH-0027_batch_5.png: mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri
# Generating caption for image: RHUH-0027_batch_6.png in case RHUH-0027
# Generated caption for RHUH-0027_batch_6.png: an mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri
# Generating caption for image: RHUH-0027_batch_7.png in case RHUH-0027
# Generated caption for RHUH-0027_batch_7.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0027_batch_8.png in case RHUH-0027
# Generated caption for RHUH-0027_batch_8.png: a black and white image of a number of dots
# Captions saved for case RHUH-0027.
# Memory cleared for case RHUH-0027
# Found 8 image files for case RHUH-0028
# Generating caption for image: RHUH-0028_batch_1.png in case RHUH-0028
# Generated caption for RHUH-0028_batch_1.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0028_batch_2.png in case RHUH-0028
# Generated caption for RHUH-0028_batch_2.png: an mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri
# Generating caption for image: RHUH-0028_batch_3.png in case RHUH-0028
# Generated caption for RHUH-0028_batch_3.png: an mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri
# Generating caption for image: RHUH-0028_batch_4.png in case RHUH-0028
# Generated caption for RHUH-0028_batch_4.png: an mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri
# Generating caption for image: RHUH-0028_batch_5.png in case RHUH-0028
# Generated caption for RHUH-0028_batch_5.png: a black and white image of a number of different types of teeth
# Generating caption for image: RHUH-0028_batch_6.png in case RHUH-0028
# Generated caption for RHUH-0028_batch_6.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0028_batch_7.png in case RHUH-0028
# Generated caption for RHUH-0028_batch_7.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0028_batch_8.png in case RHUH-0028
# Generated caption for RHUH-0028_batch_8.png: a black and white image of a black and white image of a black and white image of a black and
# Captions saved for case RHUH-0028.
# Memory cleared for case RHUH-0028
# Found 9 image files for case RHUH-0029
# Generating caption for image: RHUH-0029_batch_1.png in case RHUH-0029
# Generated caption for RHUH-0029_batch_1.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0029_batch_2.png in case RHUH-0029
# Generated caption for RHUH-0029_batch_2.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0029_batch_3.png in case RHUH-0029
# Generated caption for RHUH-0029_batch_3.png: a black and white image of a bunch of flowers
# Generating caption for image: RHUH-0029_batch_4.png in case RHUH-0029
# Generated caption for RHUH-0029_batch_4.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0029_batch_5.png in case RHUH-0029
# Generated caption for RHUH-0029_batch_5.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0029_batch_6.png in case RHUH-0029
# Generated caption for RHUH-0029_batch_6.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0029_batch_7.png in case RHUH-0029
# Generated caption for RHUH-0029_batch_7.png: an image of a large group of small, round, black and white objects
# Generating caption for image: RHUH-0029_batch_8.png in case RHUH-0029
# Generated caption for RHUH-0029_batch_8.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0029_batch_9.png in case RHUH-0029
# Generated caption for RHUH-0029_batch_9.png: a black and white image of a number of different objects
# Captions saved for case RHUH-0029.
# Memory cleared for case RHUH-0029
# Found 7 image files for case RHUH-0030
# Generating caption for image: RHUH-0030_batch_1.png in case RHUH-0030
# Generated caption for RHUH-0030_batch_1.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0030_batch_2.png in case RHUH-0030
# Generated caption for RHUH-0030_batch_2.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0030_batch_3.png in case RHUH-0030
# Generated caption for RHUH-0030_batch_3.png: a black and white image of a bunch of flowers
# Generating caption for image: RHUH-0030_batch_4.png in case RHUH-0030
# Generated caption for RHUH-0030_batch_4.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0030_batch_5.png in case RHUH-0030
# Generated caption for RHUH-0030_batch_5.png: a black and white image of a number of diamonds
# Generating caption for image: RHUH-0030_batch_6.png in case RHUH-0030
# Generated caption for RHUH-0030_batch_6.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0030_batch_7.png in case RHUH-0030
# Generated caption for RHUH-0030_batch_7.png: a black and white image of a number of circles
# Captions saved for case RHUH-0030.
# Memory cleared for case RHUH-0030
# Found 6 image files for case RHUH-0031
# Generating caption for image: RHUH-0031_batch_1.png in case RHUH-0031
# Generated caption for RHUH-0031_batch_1.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0031_batch_2.png in case RHUH-0031
# Generated caption for RHUH-0031_batch_2.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0031_batch_3.png in case RHUH-0031
# Generated caption for RHUH-0031_batch_3.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0031_batch_4.png in case RHUH-0031
# Generated caption for RHUH-0031_batch_4.png: a black and white image of a number of diamonds
# Generating caption for image: RHUH-0031_batch_5.png in case RHUH-0031
# Generated caption for RHUH-0031_batch_5.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0031_batch_6.png in case RHUH-0031
# Generated caption for RHUH-0031_batch_6.png: an mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri
# Captions saved for case RHUH-0031.
# Memory cleared for case RHUH-0031
# Found 9 image files for case RHUH-0032
# Generating caption for image: RHUH-0032_batch_1.png in case RHUH-0032
# Generated caption for RHUH-0032_batch_1.png: a black and white image of a bunch of flowers
# Generating caption for image: RHUH-0032_batch_2.png in case RHUH-0032
# Generated caption for RHUH-0032_batch_2.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0032_batch_3.png in case RHUH-0032
# Generated caption for RHUH-0032_batch_3.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0032_batch_4.png in case RHUH-0032
# Generated caption for RHUH-0032_batch_4.png: an mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri
# Generating caption for image: RHUH-0032_batch_5.png in case RHUH-0032
# Generated caption for RHUH-0032_batch_5.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0032_batch_6.png in case RHUH-0032
# Generated caption for RHUH-0032_batch_6.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0032_batch_7.png in case RHUH-0032
# Generated caption for RHUH-0032_batch_7.png: a black and white photo of a group of dots
# Generating caption for image: RHUH-0032_batch_8.png in case RHUH-0032
# Generated caption for RHUH-0032_batch_8.png: a black and white image of a group of dots
# Generating caption for image: RHUH-0032_batch_9.png in case RHUH-0032
# Generated caption for RHUH-0032_batch_9.png: a black and white image of several different types of eyes
# Captions saved for case RHUH-0032.
# Memory cleared for case RHUH-0032
# Found 7 image files for case RHUH-0033
# Generating caption for image: RHUH-0033_batch_1.png in case RHUH-0033
# Generated caption for RHUH-0033_batch_1.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0033_batch_2.png in case RHUH-0033
# Generated caption for RHUH-0033_batch_2.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0033_batch_3.png in case RHUH-0033
# Generated caption for RHUH-0033_batch_3.png: an image of a number of different types of diamonds
# Generating caption for image: RHUH-0033_batch_4.png in case RHUH-0033
# Generated caption for RHUH-0033_batch_4.png: an image of several different sizes of diamonds
# Generating caption for image: RHUH-0033_batch_5.png in case RHUH-0033
# Generated caption for RHUH-0033_batch_5.png: a black and white image of a number of different types of diamonds
# Generating caption for image: RHUH-0033_batch_6.png in case RHUH-0033
# Generated caption for RHUH-0033_batch_6.png: a black and white image of a number of diamonds
# Generating caption for image: RHUH-0033_batch_7.png in case RHUH-0033
# Generated caption for RHUH-0033_batch_7.png: an mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri
# Captions saved for case RHUH-0033.
# Memory cleared for case RHUH-0033
# Found 7 image files for case RHUH-0034
# Generating caption for image: RHUH-0034_batch_1.png in case RHUH-0034
# Generated caption for RHUH-0034_batch_1.png: a set of four rows of diamonds on a black background
# Generating caption for image: RHUH-0034_batch_2.png in case RHUH-0034
# Generated caption for RHUH-0034_batch_2.png: an image of several different types of diamonds
# Generating caption for image: RHUH-0034_batch_3.png in case RHUH-0034
# Generated caption for RHUH-0034_batch_3.png: a black and white image of a number of different types of diamonds
# Generating caption for image: RHUH-0034_batch_4.png in case RHUH-0034
# Generated caption for RHUH-0034_batch_4.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0034_batch_5.png in case RHUH-0034
# Generated caption for RHUH-0034_batch_5.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0034_batch_6.png in case RHUH-0034
# Generated caption for RHUH-0034_batch_6.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0034_batch_7.png in case RHUH-0034
# Generated caption for RHUH-0034_batch_7.png: a black and white image of a group of small fish
# Captions saved for case RHUH-0034.
# Memory cleared for case RHUH-0034
# Found 7 image files for case RHUH-0035
# Generating caption for image: RHUH-0035_batch_1.png in case RHUH-0035
# Generated caption for RHUH-0035_batch_1.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0035_batch_2.png in case RHUH-0035
# Generated caption for RHUH-0035_batch_2.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0035_batch_3.png in case RHUH-0035
# Generated caption for RHUH-0035_batch_3.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0035_batch_4.png in case RHUH-0035
# Generated caption for RHUH-0035_batch_4.png: the different phases of the moon, including the phases of the moon and the phases of the phases of the
# Generating caption for image: RHUH-0035_batch_5.png in case RHUH-0035
# Generated caption for RHUH-0035_batch_5.png: a black and white image of a number of different circles
# Generating caption for image: RHUH-0035_batch_6.png in case RHUH-0035
# Generated caption for RHUH-0035_batch_6.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0035_batch_7.png in case RHUH-0035
# Generated caption for RHUH-0035_batch_7.png: a black and white image of a number of small circles
# Captions saved for case RHUH-0035.
# Memory cleared for case RHUH-0035
# Found 8 image files for case RHUH-0036
# Generating caption for image: RHUH-0036_batch_1.png in case RHUH-0036
# Generated caption for RHUH-0036_batch_1.png: an mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri
# Generating caption for image: RHUH-0036_batch_2.png in case RHUH-0036
# Generated caption for RHUH-0036_batch_2.png: a black and white image of a bunch of flowers
# Generating caption for image: RHUH-0036_batch_3.png in case RHUH-0036
# Generated caption for RHUH-0036_batch_3.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0036_batch_4.png in case RHUH-0036
# Generated caption for RHUH-0036_batch_4.png: mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri
# Generating caption for image: RHUH-0036_batch_5.png in case RHUH-0036
# Generated caption for RHUH-0036_batch_5.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0036_batch_6.png in case RHUH-0036
# Generated caption for RHUH-0036_batch_6.png: a black and white photo of a group of dots
# Generating caption for image: RHUH-0036_batch_7.png in case RHUH-0036
# Generated caption for RHUH-0036_batch_7.png: a black and white polka dot pattern on a black background
# Generating caption for image: RHUH-0036_batch_8.png in case RHUH-0036
# Generated caption for RHUH-0036_batch_8.png: a black and white image of a large group of asteroids
# Captions saved for case RHUH-0036.
# Memory cleared for case RHUH-0036
# Found 6 image files for case RHUH-0037
# Generating caption for image: RHUH-0037_batch_1.png in case RHUH-0037
# Generated caption for RHUH-0037_batch_1.png: a black and white image of a group of elephants
# Generating caption for image: RHUH-0037_batch_2.png in case RHUH-0037
# Generated caption for RHUH-0037_batch_2.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0037_batch_3.png in case RHUH-0037
# Generated caption for RHUH-0037_batch_3.png: a black and white image of a bunch of flowers
# Generating caption for image: RHUH-0037_batch_4.png in case RHUH-0037
# Generated caption for RHUH-0037_batch_4.png: a black and white image of a group of small animals
# Generating caption for image: RHUH-0037_batch_5.png in case RHUH-0037
# Generated caption for RHUH-0037_batch_5.png: a black and white image of a number of small circles
# Generating caption for image: RHUH-0037_batch_6.png in case RHUH-0037
# Generated caption for RHUH-0037_batch_6.png: a black and white image of water droplets
# Captions saved for case RHUH-0037.
# Memory cleared for case RHUH-0037
# Found 9 image files for case RHUH-0038
# Generating caption for image: RHUH-0038_batch_1.png in case RHUH-0038
# Generated caption for RHUH-0038_batch_1.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0038_batch_2.png in case RHUH-0038
# Generated caption for RHUH-0038_batch_2.png: a black and white image of a group of skulls
# Generating caption for image: RHUH-0038_batch_3.png in case RHUH-0038
# Generated caption for RHUH-0038_batch_3.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0038_batch_4.png in case RHUH-0038
# Generated caption for RHUH-0038_batch_4.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0038_batch_5.png in case RHUH-0038
# Generated caption for RHUH-0038_batch_5.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0038_batch_6.png in case RHUH-0038
# Generated caption for RHUH-0038_batch_6.png: a black and white image of skulls on a black background
# Generating caption for image: RHUH-0038_batch_7.png in case RHUH-0038
# Generated caption for RHUH-0038_batch_7.png: a black and white image of skulls on a black background
# Generating caption for image: RHUH-0038_batch_8.png in case RHUH-0038
# Generated caption for RHUH-0038_batch_8.png: a black and white image of skulls on a black background
# Generating caption for image: RHUH-0038_batch_9.png in case RHUH-0038
# Generated caption for RHUH-0038_batch_9.png: a black and white image of a line of circles
# Captions saved for case RHUH-0038.
# Memory cleared for case RHUH-0038
# Found 9 image files for case RHUH-0039
# Generating caption for image: RHUH-0039_batch_1.png in case RHUH-0039
# Generated caption for RHUH-0039_batch_1.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0039_batch_2.png in case RHUH-0039
# Generated caption for RHUH-0039_batch_2.png: a black and white image of a number of different objects
# Generating caption for image: RHUH-0039_batch_3.png in case RHUH-0039
# Generated caption for RHUH-0039_batch_3.png: a black and white image of a number of skulls
# Generating caption for image: RHUH-0039_batch_4.png in case RHUH-0039
# Generated caption for RHUH-0039_batch_4.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0039_batch_5.png in case RHUH-0039
# Generated caption for RHUH-0039_batch_5.png: mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri mri
# Generating caption for image: RHUH-0039_batch_6.png in case RHUH-0039
# Generated caption for RHUH-0039_batch_6.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0039_batch_7.png in case RHUH-0039
# Generated caption for RHUH-0039_batch_7.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0039_batch_8.png in case RHUH-0039
# Generated caption for RHUH-0039_batch_8.png: a black and white image of a number of fingerprints
# Generating caption for image: RHUH-0039_batch_9.png in case RHUH-0039
# Generated caption for RHUH-0039_batch_9.png: a black and white image of a group of small rocks
# Captions saved for case RHUH-0039.
# Memory cleared for case RHUH-0039
# Found 6 image files for case RHUH-0040
# Generating caption for image: RHUH-0040_batch_1.png in case RHUH-0040
# Generated caption for RHUH-0040_batch_1.png: an image of a number of different types of diamonds
# Generating caption for image: RHUH-0040_batch_2.png in case RHUH-0040
# Generated caption for RHUH-0040_batch_2.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0040_batch_3.png in case RHUH-0040
# Generated caption for RHUH-0040_batch_3.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0040_batch_4.png in case RHUH-0040
# Generated caption for RHUH-0040_batch_4.png: a black and white image of a number of circles
# Generating caption for image: RHUH-0040_batch_5.png in case RHUH-0040
# Generated caption for RHUH-0040_batch_5.png: a black and white image of a bunch of flowers
# Generating caption for image: RHUH-0040_batch_6.png in case RHUH-0040
# Generated caption for RHUH-0040_batch_6.png: a black and white image of a bunch of flowers
# Captions saved for case RHUH-0040.
# Memory cleared for case RHUH-0040
# Failed cases logged in /media/RLAB-Disk01/(final)merged_images_with_labels_order_and_folders_mask_normalized/failed_cases_blip.txt
